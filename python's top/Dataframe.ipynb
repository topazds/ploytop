# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series,DataFrame

# %%
import webbrowser
website = "https://en.wikipedia.org/wiki/NFL_win%E2%80%93loss_records"
webbrowser.open(website)
# Out:
# True

# %%
n_frame = pd.read_clipboard()

# %%
n_frame
# Out:
#    Rank          Team       Won        Lost  Tied  Pct.  First       NFL  \
# 0    28       Houston    Texans         106   134     0  0.442  2002.000
# 1     9     Baltimore    Ravens         181   154     1  0.540  1996.000
# 2    20      Carolina  Panthers         172   179     1  0.490  1995.000
# 3    29  Jacksonville   Jaguars         155   197     0  0.440  1995.000
# 4    16       Seattle  Seahawks         325   318     1  0.505  1976.000
# 5    32         Tampa       Bay  Buccaneers   250   393  1.000     0.389
# 6    25    Cincinnati   Bengals         344   408     4  0.458  1968.000
# 7    27           New   Orleans      Saints   338   427  5.000     0.442
# 8     4         Miami  Dolphins         439   341     4  0.563  1966.000
#
#    Season Total  Games Division
# 0     240   AFC  South      NaN
# 1     336   AFC  North      NaN
# 2     352   NFC  South      NaN
# 3     352   AFC  South      NaN
# 4     644   NFC   West      NaN
# 5    1976   644    NFC    South
# ...

# %%
n_frame.columns[0]
# Out:
# 'Rank'

# %%
n_frame.tail(3)['First']
# Out:
# 6    0.458
# 7    5.000
# 8    0.563
# Name: First, dtype: float64

# %%
DataFrame(n_frame.head(2),columns=['Rank'])
# Out:
#    Rank
# 0    28
# 1     9

# %%
n_frame.ix[0,0]
# Out:
# 28

# %%
n_frame
# Out:
#    Rank          Team       Won        Lost  Tied  Pct.  First       NFL  \
# 0    28       Houston    Texans         106   134     0  0.442  2002.000
# 1     9     Baltimore    Ravens         181   154     1  0.540  1996.000
# 2    20      Carolina  Panthers         172   179     1  0.490  1995.000
# 3    29  Jacksonville   Jaguars         155   197     0  0.440  1995.000
# 4    16       Seattle  Seahawks         325   318     1  0.505  1976.000
# 5    32         Tampa       Bay  Buccaneers   250   393  1.000     0.389
# 6    25    Cincinnati   Bengals         344   408     4  0.458  1968.000
# 7    27           New   Orleans      Saints   338   427  5.000     0.442
# 8     4         Miami  Dolphins         439   341     4  0.563  1966.000
#
#    Season Total  Games Division
# 0     240   AFC  South      NaN
# 1     336   AFC  North      NaN
# 2     352   NFC  South      NaN
# 3     352   AFC  South      NaN
# 4     644   NFC   West      NaN
# 5    1976   644    NFC    South
# ...

# %%
n_frame['add field'] = 'test na kub'

# %%
n_frame
# Out:
#    Rank          Team       Won        Lost  Tied  Pct.  First       NFL  \
# 0    28       Houston    Texans         106   134     0  0.442  2002.000
# 1     9     Baltimore    Ravens         181   154     1  0.540  1996.000
# 2    20      Carolina  Panthers         172   179     1  0.490  1995.000
# 3    29  Jacksonville   Jaguars         155   197     0  0.440  1995.000
# 4    16       Seattle  Seahawks         325   318     1  0.505  1976.000
# 5    32         Tampa       Bay  Buccaneers   250   393  1.000     0.389
# 6    25    Cincinnati   Bengals         344   408     4  0.458  1968.000
# 7    27           New   Orleans      Saints   338   427  5.000     0.442
# 8     4         Miami  Dolphins         439   341     4  0.563  1966.000
#
#    Season Total  Games Division    add field
# 0     240   AFC  South      NaN  test na kub
# 1     336   AFC  North      NaN  test na kub
# 2     352   NFC  South      NaN  test na kub
# 3     352   AFC  South      NaN  test na kub
# ...

# %%
n_frame["add field2"] = np.arange(9)

# %%
n_frame
# Out:
#    Rank          Team       Won        Lost  Tied  Pct.  First       NFL  \
# 0    28       Houston    Texans         106   134     0  0.442  2002.000
# 1     9     Baltimore    Ravens         181   154     1  0.540  1996.000
# 2    20      Carolina  Panthers         172   179     1  0.490  1995.000
# 3    29  Jacksonville   Jaguars         155   197     0  0.440  1995.000
# 4    16       Seattle  Seahawks         325   318     1  0.505  1976.000
# 5    32         Tampa       Bay  Buccaneers   250   393  1.000     0.389
# 6    25    Cincinnati   Bengals         344   408     4  0.458  1968.000
# 7    27           New   Orleans      Saints   338   427  5.000     0.442
# 8     4         Miami  Dolphins         439   341     4  0.563  1966.000
#
#    Season Total  Games Division    add field  add field2
# 0     240   AFC  South      NaN  test na kub           0
# 1     336   AFC  North      NaN  test na kub           1
# 2     352   NFC  South      NaN  test na kub           2
# ...

# %%
stadiums = Series(["test1",'test2'],index=[5,6])

# %%
stadiums
# Out:
# 5    test1
# 6    test2
# dtype: object
